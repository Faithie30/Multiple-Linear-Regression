# %%
# Still to add markdowns

# %% [markdown]
# # Multi-Linear Regression
#
# Multiple linear regression (MLR), also simply just knonwn as the multiple regression, is a statistical technique that uses several explanatory variables to predict the outcome of a response variable. MLR is to model the linear relationship between the explanatory (independent) variables and response (dependent) variable.
#
# - We will predict salary from all the variables in the training dataset. <br>
# - We are going to use a simple supervised learning technique: linear regression.

# %% [markdown]
# ## 1. Importing

# %%
# importing libraries 

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
import statsmodels.formula.api as smf
import numpy as np
from sklearn.linear_model import LinearRegression
from scipy import stats
from scipy.stats import pearsonr
from sklearn.metrics import mean_squared_error as mse
from math import sqrt
import plotly.graph_objects as go
from sklearn.linear_model import Ridge
from yellowbrick.datasets import load_concrete
from yellowbrick.regressor import ResidualsPlot

# %%
# Reading data into a dataframe

salaries = pd.read_csv('salary.csv')

# printing the head of the dataset
salaries.head(1)
# Out:
#     salary  exprior  yearsworked  yearsrank  market  degree  otherqual  \
# 0  53000.0        0            0          0    1.17       1          0
#
#    position  male  Field  yearsabs
# 0         1     1      3         0

# %% [markdown]
# <h1><center>Type of data</center></h1>
#
# | Continuous | Categorical | Binary |
# | --- | --- | --- |
# | Salary | position | degree |
# | exprior | field | otherqual |
# | Yearsworked | - | male |
# | market | - | - |
# | yearsranked | - | -|
# | yearsabs | - | - |
#
# <h1><center>Feature description</center></h1>
#
# | Feature | Description |
# | --- | --- |
# | exprior | Years of experience prior to working in this field |
# | Yearsworked | Years worked in this field |
# | yearsrank | Years worked at current rank |
# | market | Market value (1 = salary at market value for position, <br> <1 salary lower than market value for position,<br> >1 salary higher than market value for position) |
# | degree | Has degree (0 = no 1= yes) |
# | otherqual | Has other post-secondary qualification (0 = no, 1=yes) |
# | position | Position (1 = Junior Employee 2=Manager 3= Executive) |
# | male | 0 = no 1 1=yes |
# | Field | Field of work (1 = Engineering 2=Finance 3=Human Resource 4=Marketing) |
# | yearsabs |Years absent from work (e.g. due to illness / child rearing / personal reasons)|
#
# <h1><center>Response description</center></h1>
#
# | Response | Description |
# | --- | --- |
# | <font color='black'> salary </font>| <font color='black'>  Annual salary in dollars </font> |

# %% [markdown]
# ## 2. Cleaning data
# Data cleaning is the process of detecting and correcting corrupt or inaccurate data from a dataset, table, or database and refers to identifying incomplete, incorrect, inaccurate or irrelevant parts of the data and then replacing, modifying, or deleting the dirty or coarse data.
# ### 2.1 Examining missing values

# %%
#checking for missing values
salaries.isnull().sum()
# Out:
# salary         1
# exprior        0
# yearsworked    0
# yearsrank      0
# market         0
# degree         0
# otherqual      0
# position       0
# male           0
# Field          0
# yearsabs       0
# dtype: int64

# %%
#replacing the missing value with the mean
salaries['salary']= salaries.fillna(salaries['salary'].mean())

# %% [markdown]
# ##### What we did with the missing values in the data
#
# - We <b>filled</b> the missing value that appeared in the <b>salary</b> column with the <b>mean</b> of that column.

# %% [markdown]
# ### 2.2 Examing duplicates within the dataset

# %%
#Dropping duplicates
salaries.drop_duplicates(inplace = True)

# %% [markdown]
# ##### Dealing with duplicates within the dataset
#
# We dropped any duplicates that may exist within the dataset

# %% [markdown]
# ### 2.3 Examining outliers within the dataset
# In statistics, an outlier is an observation point that is distant from other observations.

# %%
# Check for extreme values

sns.set()
sns.set(style="whitegrid")
fig, axes = plt.subplots(1,2, figsize=(5, 5))
sns.boxplot(x=salaries["salary"], ax=axes[0], data = salaries)
sns.boxplot(x=salaries["yearsworked"], ax=axes[1],data = salaries);
q3,q1 = np.percentile(salaries, [75,25])
IQR = q3-q1

# %%
# Removing the outliers
new_salaries = salaries[~((salaries <(q1-1.5*IQR))| (salaries > (q3+1.5*IQR))).any(axis=1)]

# %% [markdown]
# ##### Outliers
#
# Using the box plot method have observed <b> two outliers</b> for the salary values, and <b>none</b> for the yearsworked values.
# How we intend on dealing with the outliers is to <b>remove </b> them, so that the model that we will build will not be affected.

# %% [markdown]
# ### 2.4 Spliting data

# %%
#one hot encoding

field = pd.get_dummies(salaries['Field'])
position = pd.get_dummies(salaries['position'])

new_field = field.rename(columns={1:'Engeneering_field',2:'Finance_field',3:'HR_field',4:'Marketing_field'})
new_position = position.rename(columns={1:'Junior_Employee_position', 2: 'Manager_position', 3:'Executive_position'})

salaries = pd.concat([salaries, new_field, new_position] ,axis=1)
salaries.drop(['HR_field','Manager_position'], axis=1,inplace=True)
# salaries.drop(['position','Field'], axis=1,inplace=True)

salaries.head(1)
# Out:
#     salary  exprior  yearsworked  yearsrank  market  degree  otherqual  \
# 0  53000.0        0            0          0    1.17       1          0
#
#    position  male  Field  yearsabs  Engeneering_field  Finance_field  \
# 0         1     1      3         0                  0              0
#
#    Marketing_field  Junior_Employee_position  Executive_position
# 0                0                         1                   0

# %%
#Split our data
x = salaries[['exprior','yearsworked','yearsrank','market','degree','otherqual','Junior_Employee_position', 'Executive_position', 'male','Engeneering_field','Finance_field','Marketing_field','yearsabs']]
y = salaries['salary']
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=0)
# y_train = pd.DataFrame(y_train)
combined = pd.concat([X_train, y_train], axis=1)
X_train.head(1)
# Out:
#      exprior  yearsworked  yearsrank  market  degree  otherqual  \
# 297        0           23         10     1.0       1          0
#
#      Junior_Employee_position  Executive_position  male  Engeneering_field  \
# 297                         0                   1     1                  0
#
#      Finance_field  Marketing_field  yearsabs
# 297              0                1         1

# %% [markdown]
# ## 3. Exploratory data analysis (EDA)

# %% [markdown]
# ### 3.1 Multi-variate graphs

# %%
X_train['exprior'] = X_train['exprior'].apply(lambda x : int(x/5)* 10)
X_train['yearsrank'] = X_train['yearsrank'].apply(lambda x : int(x/5)* 10)
X_train['yearsworked'] = X_train['yearsworked'].apply(lambda x : int(x/5)* 10)
X_train['market'] = X_train['market'].apply(lambda x : int(x/5)* 10)
X_train['yearsabs'] = X_train['yearsabs'].apply(lambda x : int(x/15)* 10)


sns.set()
sns.set(style="whitegrid")
fig, axes = plt.subplots(4,3, figsize=(15, 15))
lx = sns.boxplot(salaries.Field,combined.salary, ax=axes[0,0], data = salaries)
mx = sns.boxplot(salaries.position,combined.salary, ax=axes[0,1], data = salaries)
nx = sns.boxplot(X_train.degree,combined.salary, ax=axes[0,2], data = combined)
ox = sns.boxplot(X_train.otherqual,combined.salary, ax=axes[1,0], data = combined)
px = sns.boxplot(X_train.male,combined.salary, ax=axes[1,1], data = combined)
qx = sns.boxplot(X_train.yearsrank,combined.salary, ax=axes[1,2], data = combined)
rx = sns.boxplot(X_train.exprior,combined.salary, ax=axes[2,0], data = combined)
sx = sns.boxplot(X_train.yearsworked,combined.salary, ax=axes[2,1], data = combined)
tx = sns.boxplot(X_train.market,combined.salary, ax=axes[2,2], data = combined)
ax = sns.boxplot(X_train.yearsabs,combined.salary, ax=axes[3,0], data = combined)

lx.set_xticklabels(['Engineering', 'Finance','Human Resources','Marketing'])
mx.set_xticklabels(['Junior Employee', 'Manager','Executive'])
nx.set_xticklabels(['No', 'Yes'])
ox.set_xticklabels(['No', 'Yes'])
px.set_xticklabels(['No', 'Yes'])


plt.show()
# Out:
# C:\Users\Mc Camel RT .LAPTOP-6N3UDB08\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Mc Camel RT .LAPTOP-6N3UDB08\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Mc Camel RT .LAPTOP-6N3UDB08\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Mc Camel RT .LAPTOP-6N3UDB08\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Mc Camel RT .LAPTOP-6N3UDB08\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ## 4. Modelling
#
# <b>Hypothesis testing: </b> <br>
# H0: Does not have signficant relationship <br>
# Ha: Has significant relationship

# %% [markdown]
# ### 4.1 Fitting linear regression

# %%
# Fit regression model 
results = smf.ols('salary ~ exprior+yearsworked+yearsrank+market+degree+otherqual+Junior_Employee_position+Executive_position+male+Engeneering_field+Finance_field+Marketing_field+yearsabs', data=combined).fit()

# Inspect the results
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 salary   R-squared:                       0.817
# Model:                            OLS   Adj. R-squared:                  0.811
# Method:                 Least Squares   F-statistic:                     136.3
# Date:                Tue, 31 Mar 2020   Prob (F-statistic):          2.21e-137
# Time:                        12:30:00   Log-Likelihood:                -4120.1
# No. Observations:                 411   AIC:                             8268.
# Df Residuals:                     397   BIC:                             8324.
# Df Model:                          13
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                 1.461e+04   2903.921      5.032      0.000    8903.847    2.03e+04
# exprior                     91.6057     76.873      1.192      0.234     -59.524     242.736
# yearsworked               -214.4803     95.290     -2.251      0.025    -401.817     -27.143
# yearsrank                  873.2678     92.076      9.484      0.000     692.250    1054.286
# market                    3.078e+04   1991.479     15.454      0.000    2.69e+04    3.47e+04
# degree                   -1240.7643   1797.781     -0.690      0.490   -4775.125    2293.597
# otherqual                 2553.8684   1398.303      1.826      0.069    -195.135    5302.872
# Junior_Employee_position -6465.3904    931.305     -6.942      0.000   -8296.297   -4634.484
# Executive_position         1.01e+04    907.732     11.131      0.000    8319.828    1.19e+04
# male                       517.0020    961.805      0.538      0.591   -1373.867    2407.871
# Engeneering_field         5394.6956    893.718      6.036      0.000    3637.684    7151.707
# Finance_field             3046.4841    873.664      3.487      0.001    1328.898    4764.071
# Marketing_field             93.7722    799.148      0.117      0.907   -1477.319    1664.863
# yearsabs                   -16.2889     23.147     -0.704      0.482     -61.795      29.218
# ==============================================================================
# Omnibus:                       30.346   Durbin-Watson:                   1.988
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               43.290
# Skew:                           0.546   Prob(JB):                     3.98e-10
# Kurtosis:                       4.156   Cond. No.                         275.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## 5 Linear Regression assumptions

# %% [markdown]
# ### 5.1 Linear relationship

# %%
#scatter plot

sns.set()
# sns.set(style = 'whitegrid')
fig, axes = plt.subplots(2,5, figsize=(16,16))

sns.regplot(x=X_train['exprior'], y=y_train, ax= axes[0,0])
sns.regplot(x=X_train['yearsworked'], y=y_train,ax= axes[0,1]);
sns.regplot(x=X_train['yearsrank'], y=y_train, ax= axes[0,2])
sns.regplot(x=X_train['yearsabs'], y=y_train,ax= axes[0,3]);
sns.regplot(x=X_train['market'], y=y_train,ax= axes[0,4]);
sns.regplot(x=salaries['Field'], y=salaries['salary'],ax= axes[1,0]);
sns.regplot(x=X_train['degree'], y=y_train, ax= axes[1,1])
sns.regplot(x=X_train['otherqual'], y=y_train,ax= axes[1,2]);
sns.regplot(x=X_train['male'], y=y_train, ax= axes[1,3]);
sns.regplot(x=salaries['position'], y=salaries['salary'], ax= axes[1,4]);

# %% [markdown]
# ### 5.2 Multivariate normality

# %%
#histogram plot

fig, axes = plt.subplots(3,5, figsize=(16,16))

sns.distplot(X_train['exprior'],ax= axes[0,0])
sns.distplot(X_train['yearsworked'],ax= axes[0,1]);
sns.distplot(X_train['yearsrank'],ax= axes[0,2])
sns.distplot(X_train['yearsabs'],ax= axes[0,3]);
sns.distplot(X_train['market'],ax= axes[0,4]);
sns.distplot(salaries['Field'],ax= axes[1,0]);
sns.distplot(X_train['degree'],ax= axes[1,1])
sns.distplot(X_train['otherqual'],ax= axes[1,2]);
sns.distplot(X_train['male'],ax= axes[1,3])
sns.distplot(salaries['position'],ax= axes[1,4]);
sns.distplot(combined['salary'],ax= axes[2,0]);

# %% [markdown]
# ### 5.3 No or little multicollinearity

# %%
# 3. correlation matrix

corr = salaries.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_f6b180ca_733b_11ea_9704_409f38b53128row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f6b180ca_733b_11ea_9704_409f38b53128row0_col1 {
#             background-color:  #9dbdff;
#             color:  #000000;
#         }    #T_f6b180ca_733b_11ea_9704_409f38b53128row0_col2 {
#             background-color:  #f29072;
#             color:  #000000;
#         }    #T_f6b180ca_733b_11ea_9704_409f38b53128row0_col3 {
#             background-color:  #f6a586;
#             color:  #000000;
#         }    #T_f6b180ca_733b_11ea_9704_409f38b53128row0_col4 {
#             background-color:  #e0dbd8;
#             color:  #000000;
#         }    #T_f6b180ca_733b_11ea_9704_409f38b53128row0_col5 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_f6b180ca_733b_11ea_9704_409f38b53128row0_col6 {
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }    #T_f6b180ca_733b_11ea_9704_409f38b53128row0_col7 {
#             background-color:  #e67259;
#             color:  #000000;
#         }    #T_f6b180ca_733b_11ea_9704_409f38b53128row0_col8 {
#             background-color:  #f2c9b4;
#             color:  #000000;
#         }    #T_f6b180ca_733b_11ea_9704_409f38b53128row0_col9 {
#             background-color:  #6b8df0;
#             color:  #000000;
#         }    #T_f6b180ca_733b_11ea_9704_409f38b53128row0_col10 {
#             background-color:  #adc9fd;
#             color:  #000000;
#         }    #T_f6b180ca_733b_11ea_9704_409f38b53128row0_col11 {
#             background-color:  #f7b497;
#             color:  #000000;
#         }    #T_f6b180ca_733b_11ea_9704_409f38b53128row0_col12 {
#             background-color:  #c9d7f0;
#             color:  #000000;
#         }    #T_f6b180ca_733b_11ea_9704_409f38b53128row0_col13 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_f6b180ca_733b_11ea_9704_409f38b53128row0_col14 {
#             background-color:  #7093f3;
#             color:  #000000;
#         }    #T_f6b180ca_733b_11ea_9704_409f38b53128row0_col15 {
#             background-color:  #f08a6c;
#             color:  #000000;
#         }    #T_f6b180ca_733b_11ea_9704_409f38b53128row1_col0 {
#             background-color:  #c9d7f0;
#             color:  #000000;
#         }    #T_f6b180ca_733b_11ea_9704_409f38b53128row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f6b180ca_733b_11ea_9704_409f38b53128row1_col2 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_f6b180ca_733b_11ea_9704_409f38b53128row1_col3 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_f6b180ca_733b_11ea_9704_409f38b53128row1_col4 {
#             background-color:  #6b8df0;
#             color:  #000000;
#         }    #T_f6b180ca_733b_11ea_9704_409f38b53128row1_col5 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_f6b180ca_733b_11ea_9704_409f38b53128row1_col6 {
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }    #T_f6b180ca_733b_11ea_9704_409f38b53128row1_col7 {
#             background-color:  #e3d9d3;
#             color:  #000000;
#         }    #T_f6b180ca_733b_11ea_9704_409f38b53128row1_col8 {
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }    #T_f6b180ca_733b_11ea_9704_409f38b53128row1_col9 {
#             background-color:  #c3d5f4;
#             color:  #000000;
#         }    #T_f6b180ca_733b_11ea_9704_409f38b53128row1_col10 {
#             background-color:  #d4dbe6;
#             color:  #000000;
#         }    #T_f6b180ca_733b_11ea_9704_409f38b53128row1_col11 {
#             background-color:  #d4dbe6;
#             color:  #000000;
#         }    #T_f6b180ca_733b_11ea_9704_409f38b53128row1_col12 {
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }    #T_f6b180ca_733b_11ea_9704_409f38b53128row1_col13 {
#             background-color:  #8badfd;
#             color:  #000000;
#         }    #T_f6b180ca_733b_11ea_9704_409f38b53128row1_col14 {
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }    #T_f6b180ca_733b_11ea_9704_409f38b53128row1_col15 {
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }    #T_f6b180ca_733b_11ea_9704_409f38b53128row2_col0 {
#             background-color:  #f39778;
#             color:  #000000;
#         }    #T_f6b180ca_733b_11ea_9704_409f38b53128row2_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f6b180ca_733b_11ea_9704_409f38b53128row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f6b180ca_733b_11ea_9704_409f38b53128row2_col3 {
#             background-color:  #e0654f;
#             color:  #000000;
#         }    #T_f6b180ca_733b_11ea_9704_409f38b53128row2_col4 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_f6b180ca_733b_11ea_9704_409f38b53128row2_col5 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_f6b180ca_733b_11ea_9704_409f38b53128row2_col6 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_f6b180ca_733b_11ea_9704_409f38b53128row2_col7 {
#             background-color:  #e0654f;
#             color:  #000000;
#         }    #T_f6b180ca_733b_11ea_9704_409f38b53128row2_col8 {
#             background-color:  #ead4c8;
#             color:  #000000;
#         }    #T_f6b180ca_733b_11ea_9704_409f38b53128row2_col9 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_f6b180ca_733b_11ea_9704_409f38b53128row2_col10 {
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }    #T_f6b180ca_733b_11ea_9704_409f38b53128row2_col11 {
#             background-color:  #ead4c8;
#             color:  #000000;
#         }    #T_f6b180ca_733b_11ea_9704_409f38b53128row2_col12 {
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }    #T_f6b180ca_733b_11ea_9704_409f38b53128row2_col13 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_f6b180ca_733b_11ea_9704_409f38b53128row2_col14 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_f6b180ca_733b_11ea_9704_409f38b53128row2_col15 {
#             background-color:  #f18d6f;
#             color:  #000000;
#         }    #T_f6b180ca_733b_11ea_9704_409f38b53128row3_col0 {
#             background-color:  #f49a7b;
#             color:  #000000;
#         }    #T_f6b180ca_733b_11ea_9704_409f38b53128row3_col1 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_f6b180ca_733b_11ea_9704_409f38b53128row3_col2 {
#             background-color:  #da5a49;
#             color:  #000000;
#         }    #T_f6b180ca_733b_11ea_9704_409f38b53128row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f6b180ca_733b_11ea_9704_409f38b53128row3_col4 {
#             background-color:  #6e90f2;
#             color:  #000000;
#         }    #T_f6b180ca_733b_11ea_9704_409f38b53128row3_col5 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_f6b180ca_733b_11ea_9704_409f38b53128row3_col6 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_f6b180ca_733b_11ea_9704_409f38b53128row3_col7 {
#             background-color:  #f6a385;
#             color:  #000000;
#         }    #T_f6b180ca_733b_11ea_9704_409f38b53128row3_col8 {
#             background-color:  #e4d9d2;
#             color:  #000000;
#         }    #T_f6b180ca_733b_11ea_9704_409f38b53128row3_col9 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_f6b180ca_733b_11ea_9704_409f38b53128row3_col10 {
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }    #T_f6b180ca_733b_11ea_9704_409f38b53128row3_col11 {
#             background-color:  #e9d5cb;

# %% [markdown]
# ### 5.4 No auto-correlation

# %%
# ACF graph

from statsmodels.graphics.tsaplots import plot_acf
plot_acf(y_train)
plt.show()

# %% [markdown]
# ### 5.5 Homoscedasticity

# %%
# scatter plot

regression = LinearRegression().fit(X_train, y_train)
model = Ridge()
visualizer = ResidualsPlot(model)

# visualizer = ResidualsPlot(regression)
visualizer.fit(X_train, y_train)  
visualizer.score(X_test, y_test)  
visualizer.show();

# %% [markdown]
# ### 3.4 RSME

# %%
# RSME for training dataset
train = results.predict(X_train)

m_s_e = sqrt(mse(y_train, train))
m_s_e
# Out:
# 135790.4148464191

# %%
# RSME for test dataset
test = results.predict(X_test)

msse = sqrt(mse(y_test, test))
msse
# Out:
# 5355.286467618474

# %% [markdown]
# ##### What is the difference in the Root Mean Square Error (RMSE) between the training and test sets? Is there any evidence of overfitting?
#
# Our model performs better on the train dataset than it does on the test set. With this we can now conclude that the model is overfitted. We say this because our model shows low bias but high variance. To better train our model we need to identify relevant variables and terms that you are likely to influence our outcome that we hoping for
#
# RMSE_train is bigger than  RMSE_test by slight margin therefore there is overfitting on our model.
